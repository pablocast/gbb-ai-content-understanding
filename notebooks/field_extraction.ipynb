# %% [markdown]
# # Extract Custom Fields from Your File

# %% [markdown]
# This notebook demonstrates how to use analyzers to extract custom fields from your input files.

# %% [markdown]
# ## Analyzer Templates

# %% [markdown]
# Below is a collection of analyzer templates designed to extract fields from various input file types.
#
# These templates are highly customizable, allowing you to modify them to suit your specific needs. For additional verified templates from Microsoft, please visit [here](../analyzer_templates/README.md).

# %%
extraction_templates = {
    "contrato":            ('../analyzer_templates/contrato.json',         '../data/contrato.pdf'            )
}

# %% [markdown]
# Specify the analyzer template you want to use and provide a name for the analyzer to be created based on the template.

# %%
import uuid


ANALYZER_TEMPLATE = "contrato"
ANALYZER_ID = "field-extraction-sample-" + str(uuid.uuid4())

(analyzer_template_path, analyzer_sample_file_path) = extraction_templates[ANALYZER_TEMPLATE]

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The [AzureContentUnderstandingClient](../python/content_understanding_client.py) is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
import pandas as pd

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

AZURE_AI_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
AZURE_AI_API_VERSION = os.getenv("AZURE_AI_API_VERSION", "2024-12-01-preview")

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from src.content_understanding_client import AzureContentUnderstandingClient

credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
)
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.0rc2 (Windows-10-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential

# %% [markdown]
# ## Create Analyzer from the Template

# %%
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=analyzer_template_path)

result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# INFO:src.content_understanding_client:Analyzer field-extraction-sample-d8417119-2c9a-46b1-8eb9-2369af2bace7 create request accepted.
# INFO:src.content_understanding_client:Request 4d64282c-7ef6-4c5f-b1bf-1e3bb9f17074 in progress ...
# INFO:src.content_understanding_client:Request result is ready after 3.00 seconds.
# {
#   "id": "4d64282c-7ef6-4c5f-b1bf-1e3bb9f17074",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "field-extraction-sample-d8417119-2c9a-46b1-8eb9-2369af2bace7",
#     "description": "An\u00c3\u00a1lise de contrato de financiamento habitacional",
#     "createdAt": "2025-05-26T23:03:21Z",
#     "lastModifiedAt": "2025-05-26T23:03:25Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableBarcode": false,
#       "enableFormula": false,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "DataAssinatura": {
#           "type": "string",
#           "method": "extract",
#           "description": "Data de assinatura do contrato de financiamento habitacional. Base legal: subitem 9.1.6 do RAFCVS."
#         },
#         "NomeCompletoVendedor": {
#           "type": "string",
#           "method": "extract",
#           "description": "Nome completo do(s) vendedor(es) do im\u00c3\u00b3vel. Subitem 11.5.2 do RAFCVS."
#         },
#         "CPF_CNPJVendedor": {
#           "type": "string",
#           "method": "extract",
#           "description": "CPF ou CNPJ do vendedor. Subitem 11.5.2 do RAFCVS."
#         },
#         "EstadoCivilVendedor": {
#           "type": "string",
#           "method": "extract",
#           "description": "Estado civil declarado do vendedor no contrato.",
#           "enum": [
#             "solteiro",
#             "casado",
#             "divorciado",
#             "viuvo",
#             "outro"
#           ]
#         },
#         "NomeConjugeVendedor": {
#           "type": "string",
#           "method": "extract",
#           "description": "Nome do c\u00c3\u00b4njuge do vendedor, quando aplic\u00c3\u00a1vel. Subitem 11.5.2 do RAFCVS."
#         },
#         "CPF_CNPJConjugeVendedor": {
#           "type": "string",
#           "method": "extract",
#           "description": "CPF ou CNPJ do c\u00c3\u00b4njuge do vendedor, quando aplic\u00c3\u00a1vel. Subitem 11.5.2 do RAFCVS."
#         },
#         "ParticipantesRenda": {
#           "type": "array",
#           "method": "extract",
#           "description": "Identifica\u00c3\u00a7\u00c3\u00a3o de todos os participantes que comp\u00c3\u00b5em a renda familiar no financiamento. Subitem 4.4.2 do FP091.",
#           "items": {
#             "type": "object",
#             "properties": {
#               "nome": {
#                 "type": "string",
#                 "description": "Nome do participante da renda."
#               },
#               "CPF_CNPJ": {
#                 "type": "string",
#                 "description": "CPF ou CNPJ do participante da renda."
#               },
#               "PercentualRenda": {
#                 "type": "number",
#                 "description": "Percentual da renda total que cada participante contribui para o financiamento."
#               }
#             }
#           }
#         },
#         "CPF_CNPJMutuarioPrincipal": {
#           "type": "string",
#           "method": "extract",
#           "description": "CPF ou CNPJ do mutu\u00c3\u00a1rio principal (titular do financiamento). Subitens 4.36 do FP091 e 11.5.1 do RAFCVS."
#         },
#         "NomeMutuarioPrincipal": {
#           "type": "string",
#           "method": "extract",
#           "description": "Nome completo do mutu\u00c3\u00a1rio principal. Subitem 9.1.2 do RAFCVS e 4.36 do FP091."
#         },
#         "DataNascimentoMutuarioPrincipal": {
#           "type": "string",
#           "method": "extract",
#           "description": "Data de nascimento do mutu\u00c3\u00a1rio principal. Subitem 4.36 do FP091."
#         },
#         "IdentidadeMutuarioPrincipal": {
#           "type": "string",
#           "method": "extract",
#           "description": "N\u00c3\u00bamero do RG (ou outro documento de identidade v\u00c3\u00a1lido) do mutu\u00c3\u00a1rio principal."
#         },
#         "EstadoCivilMutuario": {
#           "type": "string",
#           "method": "extract",
#           "description": "Estado civil do mutu\u00c3\u00a1rio principal conforme contrato.",
#           "enum": [
#             "solteiro",
#             "casado",
#             "divorciado",
#             "viuvo",
#             "outro"
#           ]
#         },
#         "NomeConjugeCodevedorMutuario": {
#           "type": "string",
#           "description": "Nome do c\u00c3\u00b4njuge ou codevedor do mutu\u00c3\u00a1rio, se houver. Subitem 11.5.2 do RAFCVS."
#         },
#         "CPF_CNPJConjugeCodevedorMutuario": {
#           "type": "string",
#           "method": "extract",
#           "description": "CPF ou CNPJ do c\u00c3\u00b4njuge ou codevedor do mutu\u00c3\u00a1rio, se houver. Subitem 11.5.2 do RAFCVS."
#         },
#         "EnderecoImovel": {
#           "type": "array",
#           "method": "extract",
#           "description": "Detalhes do endere\u00c3\u00a7o do im\u00c3\u00b3vel financiado. Subitem 9.1.5 do RAFCVS.",
#           "items": {
#             "type": "object",
#             "properties": {
#               "street": {
#                 "type": "string",
#                 "description": "Nome da rua."
#               },
#               "number": {
#                 "type": "string",
#                 "description": "N\u00c3\u00bamero do im\u00c3\u00b3vel."
#               },
#               "apartment": {
#                 "type": "string",
#                 "description": "Apt./Bloco/Unidade, se aplic\u00c3\u00a1vel."
#               },
#               "cep": {
#                 "type": "string",
#                 "description": "C\u00c3\u00b3digo postal (CEP)."
#               },
#               "city": {
#                 "type": "string",
#                 "description": "Cidade onde o im\u00c3\u00b3vel est\u00c3\u00a1 localizado."
#               },
#               "state": {
#                 "type": "string",
#                 "description": "Estado onde o im\u00c3\u00b3vel est\u00c3\u00a1 localizado."
#               }
#             }
#           }
#         },
#         "MunicipioImovel": {
#           "type": "string",
#           "method": "extract",
#           "description": "Munic\u00c3\u00adpio onde est\u00c3\u00a1 localizado o im\u00c3\u00b3vel. Subitem 9.1.5 do RAFCVS.",
#           "examples": [
#             "S\u00c3\u00a3o Paulo",
#             "Rio de Janeiro",
#             "Belo Horizonte",
#             "Curitiba"
#           ]
#         },
#         "AgenteFinanceiroOrigem": {
#           "type": "string",
#           "method": "extract",
#           "description": "Nome da institui\u00c3\u00a7\u00c3\u00a3o financeira respons\u00c3\u00a1vel pela concess\u00c3\u00a3o do financiamento (AF original)."
#         },
#         "VendedorPessoaJuridica": {
#           "type": "string",
#           "method": "classify",
#           "description": "Identifica\u00c3\u00a7\u00c3\u00a3o se o vendedor \u00c3\u00a9 uma pessoa jur\u00c3\u00addica (empresa, construtora, etc.).",
#           "enum": [
#             "Sim",
#             "Nao"
#           ],
#           "enumDescriptions": {
#             "Sim": "Vendedor \u00c3\u00a9 uma pessoa jur\u00c3\u00addica (empresa, construtora, etc.).",
#             "Nao": "Vendedor n\u00c3\u00a3o \u00c3\u00a9 uma pessoa jur\u00c3\u00addica "
#           }
#         },
#         "MutuarioUnicoParticipante": {
#           "type": "string",
#           "method": "classify",
#           "description": "Indica se apenas o mutu\u00c3\u00a1rio principal est\u00c3\u00a1 envolvido ou se h\u00c3\u00a1 outros participantes/codevedores.",
#           "enum": [
#             "Sim",
#             "Nao"
#           ],
#           "enumDescriptions": {
#             "Sim": "Apenas o mutu\u00c3\u00a1rio principal est\u00c3\u00a1 envolvido.",
#             "Nao": "Existem outros participantes/codevedores envolvidos."
#           }
#         },
#         "MutuarioAutonomo": {
#           "type": "string",
#           "method": "classify",
#           "description": "Verificar se o mutu\u00c3\u00a1rio principal \u00c3\u00a9 aut\u00c3\u00b4nomo ou possui ocupa\u00c3\u00a7\u00c3\u00a3o similar. Subitem 4.18.5 do FP091.",
#           "enum": [
#             "Sim",
#             "Nao"
#           ],
#           "enumDescriptions": {
#             "Sim": "Mutu\u00c3\u00a1rio principal \u00c3\u00a9 aut\u00c3\u00b4nomo ou possui ocupa\u00c3\u00a7\u00c3\u00a3o similar.",
#             "Nao": "Mutu\u00c3\u00a1rio principal n\u00c3\u00a3o \u00c3\u00a9 aut\u00c3\u00b4nomo."
#           }
#         },
#         "ComprovacaoRegularizacaoFundiaria": {
#           "type": "string",
#           "method": "classify",
#           "description": "Para contratos do tipo TOPOC, verificar se h\u00c3\u00a1 comprova\u00c3\u00a7\u00c3\u00a3o de regulariza\u00c3\u00a7\u00c3\u00a3o fundi\u00c3\u00a1ria. Subitens 4.9 e 4.50 do FP091.",
#           "enum": [
#             "Sim",
#             "Nao"
#           ],
#           "enumDescriptions": {
#             "Sim": "H\u00c3\u00a1 comprova\u00c3\u00a7\u00c3\u00a3o de regulariza\u00c3\u00a7\u00c3\u00a3o fundi\u00c3\u00a1ria.",
#             "Nao": "N\u00c3\u00a3o h\u00c3\u00a1 comprova\u00c3\u00a7\u00c3\u00a3o de regulariza\u00c3\u00a7\u00c3\u00a3o fundi\u00c3\u00a1ria."
#           }
#         },
#         "ValorFinanciamento": {
#           "type": "number",
#           "method": "extract",
#           "description": "Valor concedido no financiamento habitacional. Subitem 2.4 do RAFCVS."
#         },
#         "ValorCompraVenda": {
#           "type": "number",
#           "method": "extract",
#           "description": "Valor acordado para compra e venda do im\u00c3\u00b3vel."
#         },
#         "ValorGarantiaAvaliacao": {
#           "type": "number",
#           "method": "extract",
#           "description": "Valor de garantia ou avalia\u00c3\u00a7\u00c3\u00a3o do im\u00c3\u00b3vel. Subitem 1.6 do RAFCVS."
#         },
#         "TaxaJuros": {
#           "type": "number",
#           "method": "extract",
#           "description": "Taxa de juros do contrato de financiamento. Subitem 2.3 do RAFCVS."
#         },
#         "PrazoFinanciamento": {
#           "type": "string",
#           "method": "extract",
#           "description": "Prazo total do financiamento, em meses ou anos. Subitem 2.3 do RAFCVS."
#         },
#         "PlanoReajustamento": {
#           "type": "string",
#           "method": "extract",
#           "description": "Plano utilizado para reajuste das presta\u00c3\u00a7\u00c3\u00b5es (ex: SAC, Price, TR, etc.). Subitem 2.1 do RAFCVS.",
#           "enum": [
#             "SAC",
#             "Price",
#             "TR",
#             "outro"
#           ]
#         },
#         "SistemaAmortizacao": {
#           "type": "string",
#           "method": "extract",
#           "description": "Tipo de sistema de amortiza\u00c3\u00a7\u00c3\u00a3o do contrato (ex: SAC, SAM, Price). Subitem 2.2 do RAFCVS e 4.18.9 do FP091.",
#           "enum": [
#             "SAC",
#             "SAM",
#             "Price",
#             "outro"
#           ]
#         },
#         "DataPrimeiraPrestacao": {
#           "type": "string",
#           "method": "extract",
#           "description": "Data prevista ou efetiva do pagamento da primeira parcela. Deve ser postada ap\u00c3\u00b3s a assinatura do contrato. Subitem 2.5 do RAFCVS."
#         },
#         "RegistradoCRI": {
#           "type": "string",
#           "method": "classify",
#           "description": "Indica se o contrato ou im\u00c3\u00b3vel est\u00c3\u00a1 registrado no Cart\u00c3\u00b3rio de Registro de Im\u00c3\u00b3veis (CRI). Subitem 10.1 do MNPO e Cap\u00c3\u00adtulo II da Resolu\u00c3\u00a7\u00c3\u00a3o 468/2022.",
#           "enum": [
#             "Sim",
#             "Nao"
#           ],
#           "enumDescriptions": {
#             "Sim": "Contrato/im\u00c3\u00b3vel est\u00c3\u00a1 registrado no Cart\u00c3\u00b3rio de Registro de Im\u00c3\u00b3veis (CRI).",
#             "Nao": "Contrato/im\u00c3\u00b3vel n\u00c3\u00a3o est\u00c3\u00a1 registrado no Cart\u00c3\u00b3rio de Registro de Im\u00c3\u00b3veis (CRI)."
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "scenario": "document"
#   }
# }

# %% [markdown]
# ## Extract Fields Using the Analyzer

# %% [markdown]
# After the analyzer is successfully created, we can use it to analyze our input files.

# %%
response = client.begin_analyze(ANALYZER_ID, file_location=analyzer_sample_file_path)
result = client.poll_result(response)
# Out:
# INFO:src.content_understanding_client:Analyzing file ../data/contrato.pdf with analyzer: field-extraction-sample-d8417119-2c9a-46b1-8eb9-2369af2bace7
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request 3677de0f-34f1-42b0-ba96-34e2baee575b in progress ...
# INFO:src.content_understanding_client:Request result is ready after 16.92 seconds.

# %%
# helper function to extract from nested JSON
def extract_fields_from_value_array(value_array):
    """
    Extracts fields from a valueArray, returning a dictionary:
    {
        field_name: {
            "value": ...,
            "confidence": ...,
            "source": ...
        },
        ...
    }
    """
    result = {}
    for item in value_array:
        value_object = item.get("valueObject", {})
        for key, field in value_object.items():
            # Determine the value key dynamically
            value = (
                field.get("valueString")
                or field.get("valueNumber")
                or field.get("valueDate")
                or field.get("valueBoolean")
                or field.get("valueArray")
                or field.get("valueObject")
            )
            result[key] = {
                "value": value,
                "confidence": field.get("confidence"),
                "source": field.get("source"),
            }
    return result

# %%
data = []

for fields, value in result["result"]["contents"][0]["fields"].items():
    if value.get('type') != 'array':
        fields_values = value.get('valueString') or value.get('valueDate') or value.get('valueNumber') 
        if isinstance(fields_values, str):
            fields_values = fields_values.replace(",", "").replace(".", "").lower()
        confidence = value.get('confidence')
        source = value.get('source', {})
        data.append([fields, fields_values, confidence, source])
    # If the value is a valueArray, extract fields from it
    else:
        value_array = value.get('valueArray', [])
        extracted_fields = extract_fields_from_value_array(value_array)
        data.append([fields, json.dumps(extracted_fields), None, None])  # Append the field name

      
df = pd.DataFrame(data, columns=["Field", "Value", "Confidence", "Source"])
df.to_csv("../results/extracted_fields.csv", index=False)

# %% [markdown]
# ## Clean Up
# Optionally, delete the sample analyzer from your resource. In typical usage scenarios, you would analyze multiple files using the same analyzer.

# %%
client.delete_analyzer(ANALYZER_ID)
